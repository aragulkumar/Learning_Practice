# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

ypoints = np.array([3,9,11,5])

plt.plot(ypoints, marker = 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]

x2 = [1, 2, 3, 4, 5]
y2 = [1, 3, 5, 7, 9]


plt.scatter(x1,y1,marker ='o',color ='blue', label = 'circle points')
plt.scatter(x2,y2,marker='s',color='red',label='square points')

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Circle and square in same plot")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,6])
y = np.array([3,6,5,7,2,7])

plt.subplot(3,1,1)
plt.plot(x,y)

x = np.array([1,2,3,4])
y = np.array([4,6,2,5])

plt.subplot(3,1,2)
plt.plot(x,y)


x = np.array([1,2,3,4])
y = np.array([4,6,2,5])

plt.subplot(3,1,3)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([11,22,33,44,55,66,77,88])
y = np.array([9,8,7,6,5,4,3,2])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()
